# %%
## TRABAJO FINAL: Camila Araya

# En el repositorio donde desarrollarón la página, implementar lo visto anterior mente con su página
# Desarrollar la descarga de contenido desde la pagina "https://www.hites.com/belleza/perfumes/" HITES = CATEGORÍA PERFUMES
# Importar beautifulsoap4
# Importar Requests
# Obtener nombre de los productos
# Obtener precio de los productos

# %%
## Instalar beautifulsoap4 
pip install beautifulsoup4
# Out:
# ...
#      -------------------------------------- 128.2/128.2 kB 7.9 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.2.2 -> 22.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
## Instalar request 
pip install requests
# Out:
# ...
#      ---------------------------------------- 62.8/62.8 kB ? eta 0:00:00
# ...
#      ---------------------------------------- 140.6/140.6 kB ? eta 0:00:00
# ...
#      ---------------------------------------- 61.5/61.5 kB ? eta 0:00:00
# ...
#      ---------------------------------------- 161.1/161.1 kB ? eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The script normalizer.exe is installed in 'c:\Users\camil\AppData\Local\Programs\Python\Python310\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#
# [notice] A new release of pip available: 22.2.2 -> 22.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# requests es para obtener una página web
import requests

# Cargando BeautifulSoap para obtener la información almacenada en la página
from bs4 import BeautifulSoup

# nos permite realizar búsquedas a traves de expresiones regulares
import re

# %%
# Página elegida: Paris (categoría perfumes)
url = "https://www.hites.com/belleza/perfumes/"

# Llamada tradicional
page = requests.get(url)

print(page)

# El N° 200 valida que nos respondió bien

page = BeautifulSoup(page.content, 'html.parser')
print(page.prettify())
# Out:
# <Response [200]>
# <!DOCTYPE html>
# <html lang="es">
#  <head>
#   <!--[if gt IE 9]><!-->
#   <script src="/on/demandware.static/Sites-HITES-Site/-/default/v1670685469298/js/imageReplacement.js" type="text/javascript">
#   </script>
#   <script defer="" src="/on/demandware.static/Sites-HITES-Site/-/default/v1670685469298/js/main.js" type="text/javascript">
#   </script>
#   <script defer="" src="/on/demandware.static/Sites-HITES-Site/-/default/v1670685469298/js/menuV2.js" type="text/javascript">
#   </script>
#   <script defer="" src="/on/demandware.static/Sites-HITES-Site/-/default/v1670685469298/lib/js/picturefill.min.js" type="text/javascript">
#   </script>
#   <script src="/on/demandware.static/Sites-HITES-Site/-/default/v1670685469298/lib/js/jRespond.min.js" type="text/javascript">
#   </script>
#   <script defer="" src="/on/demandware.static/Sites-HITES-Site/-/default/v1670685469298/js/search.js" type="text/javascript">
#   </script>
# ...

# %%
all_products = page.find_all(class_="col-6 col-lg-4 px-0")
print(len(all_products))

for product in all_products:
    # obteniendo el nombre de los perfumes
    name_product = product.find(class_="link product-name--bundle")
    print(name_product.string)

    #obteniendo el precio
    price_product = product.find(class_="value")

    if price_product.string is None:
        print("Producto sin oferta")
        
        price = price_product.find(text=re.compile("\$"))
        print(int(price.replace("\n","").replace(" ","").replace("Oferta","").replace("$","").replace(".","")))
    else:
        print(int(price_product.string.replace("\n","").replace(" ","").replace("Oferta","").replace("$","").replace(".","")))
# Out:
# 24
# Perfume Antonio Banderas Mediterráneo Edición Limitada / 200 Ml / Edt /
# 14990
# Perfume Paco Rabanne One Million / 100 Ml / Edt /
# 59990
# Perfume mujer Edición Limitada Halloween / 100ml / Eau De Toilette
# 28990
# Perfume Hombre Polo Red Rush Ralph Lauren / 75 Ml / Eau De Toilette
# 39990
# Perfume mujer Tous Women / 30 Ml
# 19990
# Perfume mujer Halloween / 50ml / Eau De Toilette
# 19990
# Perfume mujer Nina Nina Ricci / 30 Ml / Edt
# 24990
# Perfume Hombre Azzaro Pour Homme Azzaro / 100 Ml / Eau De Toilette
# 34990
# Perfume mujer Tous Edp 30Ml Edl
# 19990
# Perfume Hombre Man Hero Halloween / 75 Ml / Eau De Toilette
# 24990
# Perfume Hombre Spirit Of The Brave Intense Diesel / 75 Ml / Eau De Parfum
# 36990
# Perfume Hombre Quartz Men Molyneux / 100 Ml / Eau De Toilette
# 19990
# Perfume mujer Halloween Magic 100Ml
# 32990
# Set De Perfumería Mediterraneo Antonio Bandera / 100ml / Eau De Toilette + Desodorante 150 Ml
# Producto sin oferta
# 14990
# ...
